# %%
# https://universe.roboflow.com/roboflow-100/construction-safety-gsnvb/dataset/2
#Dataset para download das imagens de treinamento

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='road.jpg'
# Out:
# Ultralytics YOLOv8.0.39 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/road.jpg: 448x640 9 persons, 3 cars, 3 trucks, 4 traffic lights, 1 dog, 2 handbags, 52.1ms
# Speed: 0.8ms pre-process, 52.1ms inference, 22.5ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# Couston Training Module

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/drive/MyDrive/datasets/EPI_dataset/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.39 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...
